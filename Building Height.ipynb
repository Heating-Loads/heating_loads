# %%
# check if google earth engine is working
import ee
ee.Authenticate()
ee.Initialize()
print(ee.Image("NASA/NASADEM_HGT/001").get("title").getInfo())
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=p3-y58rF_H7wixUCR10hYplXZbzDEcnlRTQwVixx4bo&tc=dR2e2Seo9YdPIzOnkgpZtjHgkJ1nR8F9fb8TWqy4bhA&cc=o-8w6j5y33lAvy-0w_iwNwPCx2An8nBnufqZVsfIWX0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=p3-y58rF_H7wixUCR10hYplXZbzDEcnlRTQwVixx4bo&tc=dR2e2Seo9YdPIzOnkgpZtjHgkJ1nR8F9fb8TWqy4bhA&cc=o-8w6j5y33lAvy-0w_iwNwPCx2An8nBnufqZVsfIWX0</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AdQt8qhTxdfxWnzQ11V0O4_pfVXREYQuV6Yulepo4y7hwaYpcfyOr6UPnyk
#
# Successfully saved authorization token.
# NASADEM: NASA NASADEM Digital Elevation 30m

# %% [markdown]
# # maddie-certificate issues

# %%
import certifi
certifi.where()
# Out:
# '/Users/Maddie/Library/Caches/pypoetry/virtualenvs/heating-loads-first-test-h1o2CJ0Z-py3.9/lib/python3.9/site-packages/certifi/cacert.pem'

# %%
certifi.__version__
# Out:
# '2022.06.15'

# %% [markdown]
# # converting js to py

# %%
path = "/Users/ssoltani/Desktop/DSSG"
import geemap as ee

import os
from geemap.conversion import *


# Convert all Earth Engine JavaScripts in a folder recursively to Python scripts.
js_to_python_dir(in_dir=path, out_dir=path, use_qgis=True)
print("Python scripts saved at: {}".format(path))
# Out:
# Converting Earth Engine JavaScripts to Python scripts...
#
# Processing 1/1: /Users/ssoltani/Desktop/DSSG/dem_validation.js
# Python scripts saved at: /Users/ssoltani/Desktop/DSSG

# %% [markdown]
# # running gee code

# %%
import ee 
#from ee_plugin import Map

# %%
#load data
glo30 = ee.ImageCollection("projects/sat-io/open-datasets/GLO-30")
glo_elev = glo30.mosaic().setDefaultProjection('EPSG:3857',None,30)

anchorage_bounds = ee.FeatureCollection('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/geoboundaries/HPSCGS-ADM2').filter(ee.Filter.eq('shapeName', 'Anchorage Municipality' ))

# %%
#proposal
#take min elevation in bldg footprint-- FABDEM

#AK buildings (Erin's OSM table)
bldgs = ee.FeatureCollection('users/edtrochim/OSM_building_AK').filter(ee.Filter.bounds(anchorage_bounds))
#Map.addLayer(bldgs, {'color': 'black'}, 'Alaskan building footprints')

# %%
#FABDEM (Forest And Buildings removed Copernicus 30m DEM)
fabdem = ee.ImageCollection("projects/sat-io/open-datasets/FABDEM")
fabdem_elev = fabdem.mosaic().setDefaultProjection('EPSG:3857',None,30)
#elev = fabdem.mosaic().setDefaultProjection(glo30.first().projection())

# %%
min_elev = fabdem_elev.reduceRegions(collection= bldgs,
                                     reducer = ee.Reducer.min(),
                                     scale = 10                   
)

min_elev_glo = glo_elev.reduceRegions(collection=bldgs,
                                      reducer=ee.Reducer.min(),
                                      scale = 10
)

max_elev = fabdem_elev.reduceRegions(collection=bldgs,
                                     reducer=ee.Reducer.max(),
                                     scale=10
)

max_elev_glo = glo_elev.reduceRegions(collection=bldgs,
                                      reducer=ee.Reducer.max(),
                                      scale=10
)

# %%
print(min_elev.first(), min_elev_glo.first())

print(max_elev.first(), max_elev_glo.first())
# Out:
# ee.Element({
#   "functionInvocationValue": {
#     "functionName": "Collection.first",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Image.reduceRegions",
#           "arguments": {
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.filter",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.loadTable",
#                       "arguments": {
#                         "tableId": {
#                           "constantValue": "users/edtrochim/OSM_building_AK"
#                         }
#                       }
#                     }
#                   },
#                   "filter": {
#                     "functionInvocationValue": {
#                       "functionName": "Filter.intersects",
#                       "arguments": {
#                         "leftField": {
#                           "constantValue": ".all"
#                         },
#                         "rightValue": {
#                           "functionInvocationValue": {
#                             "functionName": "Feature",
#                             "arguments": {
#                               "geometry": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Collection.geometry",
#                                   "arguments": {
#                                     "collection": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Collection.filter",
#                                         "arguments": {
#                                           "collection": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Collection.loadTable",
#                                               "arguments": {
#                                                 "tableId": {
#                                                   "constantValue": "projects/earthengine-legacy/assets/projects/sat-io/open-datasets/geoboundaries/HPSCGS-ADM2"
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.equals",
#                                               "arguments": {
#                                                 "leftField": {
#                                                   "constantValue": "shapeName"
#                                                 },
#                                                 "rightValue": {
#                                                   "constantValue": "Anchorage Municipality"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Image.setDefaultProjection",
#                 "arguments": {
#                   "crs": {
#                     "functionInvocationValue": {
#                       "functionName": "Projection",
#                       "arguments": {
#                         "crs": {
#                           "constantValue": "EPSG:3857"
#                         }
#                       }
#                     }
#                   },
#                   "image": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.mosaic",
#                       "arguments": {
#                         "collection": {
#                           "functionInvocationValue": {
#                             "functionName": "ImageCollection.load",
#                             "arguments": {
#                               "id": {
#                                 "constantValue": "projects/sat-io/open-datasets/FABDEM"
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "scale": {
#                     "constantValue": 30
#                   }
#                 }
#               }
#             },
#             "reducer": {
#               "functionInvocationValue": {
#                 "functionName": "Reducer.min",
#                 "arguments": {}
#               }
#             },
#             "scale": {
#               "constantValue": 10
#             }
#           }
#         }
#       }
#     }
#   }
# }) ee.Element({
#   "functionInvocationValue": {
#     "functionName": "Collection.first",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Image.reduceRegions",
#           "arguments": {
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.filter",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.loadTable",
#                       "arguments": {
#                         "tableId": {
#                           "constantValue": "users/edtrochim/OSM_building_AK"
#                         }
#                       }
#                     }
#                   },
#                   "filter": {
#                     "functionInvocationValue": {
#                       "functionName": "Filter.intersects",
#                       "arguments": {
#                         "leftField": {
#                           "constantValue": ".all"
#                         },
#                         "rightValue": {
#                           "functionInvocationValue": {
#                             "functionName": "Feature",
#                             "arguments": {
#                               "geometry": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Collection.geometry",
#                                   "arguments": {
#                                     "collection": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Collection.filter",
#                                         "arguments": {
#                                           "collection": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Collection.loadTable",
#                                               "arguments": {
#                                                 "tableId": {
#                                                   "constantValue": "projects/earthengine-legacy/assets/projects/sat-io/open-datasets/geoboundaries/HPSCGS-ADM2"
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.equals",
#                                               "arguments": {
#                                                 "leftField": {
#                                                   "constantValue": "shapeName"
#                                                 },
#                                                 "rightValue": {
#                                                   "constantValue": "Anchorage Municipality"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Image.setDefaultProjection",
#                 "arguments": {
#                   "crs": {
#                     "functionInvocationValue": {
#                       "functionName": "Projection",
#                       "arguments": {
#                         "crs": {
#                           "constantValue": "EPSG:3857"
#                         }
#                       }
#                     }
#                   },
#                   "image": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.mosaic",
#                       "arguments": {
#                         "collection": {
#                           "functionInvocationValue": {
#                             "functionName": "ImageCollection.load",
#                             "arguments": {
#                               "id": {
#                                 "constantValue": "projects/sat-io/open-datasets/GLO-30"
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "scale": {
#                     "constantValue": 30
#                   }
#                 }
#               }
#             },
#             "reducer": {
#               "functionInvocationValue": {
#                 "functionName": "Reducer.min",
#                 "arguments": {}
#               }
#             },
#             "scale": {
#               "constantValue": 10
#             }
#           }
#         }
#       }
#     }
#   }
# })
# ee.Element({
#   "functionInvocationValue": {
#     "functionName": "Collection.first",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Image.reduceRegions",
#           "arguments": {
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.filter",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.loadTable",
#                       "arguments": {
#                         "tableId": {
#                           "constantValue": "users/edtrochim/OSM_building_AK"
#                         }
#                       }
#                     }
#                   },
#                   "filter": {
#                     "functionInvocationValue": {
#                       "functionName": "Filter.intersects",
#                       "arguments": {
#                         "leftField": {
#                           "constantValue": ".all"
#                         },
#                         "rightValue": {
#                           "functionInvocationValue": {
#                             "functionName": "Feature",
#                             "arguments": {
#                               "geometry": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Collection.geometry",
#                                   "arguments": {
#                                     "collection": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Collection.filter",
#                                         "arguments": {
#                                           "collection": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Collection.loadTable",
#                                               "arguments": {
#                                                 "tableId": {
#                                                   "constantValue": "projects/earthengine-legacy/assets/projects/sat-io/open-datasets/geoboundaries/HPSCGS-ADM2"
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.equals",
#                                               "arguments": {
#                                                 "leftField": {
#                                                   "constantValue": "shapeName"
#                                                 },
#                                                 "rightValue": {
#                                                   "constantValue": "Anchorage Municipality"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Image.setDefaultProjection",
#                 "arguments": {
#                   "crs": {
#                     "functionInvocationValue": {
#                       "functionName": "Projection",
#                       "arguments": {
#                         "crs": {
#                           "constantValue": "EPSG:3857"
#                         }
#                       }
#                     }
#                   },
#                   "image": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.mosaic",
#                       "arguments": {
#                         "collection": {
#                           "functionInvocationValue": {
#                             "functionName": "ImageCollection.load",
#                             "arguments": {
#                               "id": {
#                                 "constantValue": "projects/sat-io/open-datasets/FABDEM"
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "scale": {
#                     "constantValue": 30
#                   }
#                 }
#               }
#             },
#             "reducer": {
#               "functionInvocationValue": {
#                 "functionName": "Reducer.max",
#                 "arguments": {}
#               }
#             },
#             "scale": {
#               "constantValue": 10
#             }
#           }
#         }
#       }
#     }
#   }
# }) ee.Element({
#   "functionInvocationValue": {
#     "functionName": "Collection.first",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Image.reduceRegions",
#           "arguments": {
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.filter",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.loadTable",
#                       "arguments": {
#                         "tableId": {
#                           "constantValue": "users/edtrochim/OSM_building_AK"
#                         }
#                       }
#                     }
#                   },
#                   "filter": {
#                     "functionInvocationValue": {
#                       "functionName": "Filter.intersects",
#                       "arguments": {
#                         "leftField": {
#                           "constantValue": ".all"
#                         },
#                         "rightValue": {
#                           "functionInvocationValue": {
#                             "functionName": "Feature",
#                             "arguments": {
#                               "geometry": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Collection.geometry",
#                                   "arguments": {
#                                     "collection": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Collection.filter",
#                                         "arguments": {
#                                           "collection": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Collection.loadTable",
#                                               "arguments": {
#                                                 "tableId": {
#                                                   "constantValue": "projects/earthengine-legacy/assets/projects/sat-io/open-datasets/geoboundaries/HPSCGS-ADM2"
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.equals",
#                                               "arguments": {
#                                                 "leftField": {
#                                                   "constantValue": "shapeName"
#                                                 },
#                                                 "rightValue": {
#                                                   "constantValue": "Anchorage Municipality"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Image.setDefaultProjection",
#                 "arguments": {
#                   "crs": {
#                     "functionInvocationValue": {
#                       "functionName": "Projection",
#                       "arguments": {
#                         "crs": {
#                           "constantValue": "EPSG:3857"
#                         }
#                       }
#                     }
#                   },
#                   "image": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.mosaic",
#                       "arguments": {
#                         "collection": {
#                           "functionInvocationValue": {
#                             "functionName": "ImageCollection.load",
#                             "arguments": {
#                               "id": {
#                                 "constantValue": "projects/sat-io/open-datasets/GLO-30"
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "scale": {
#                     "constantValue": 30
#                   }
#                 }
#               }
#             },
#             "reducer": {
#               "functionInvocationValue": {
#                 "functionName": "Reducer.max",
#                 "arguments": {}
#               }
#             },
#             "scale": {
#               "constantValue": 10
#             }
#           }
#         }
#       }
#     }
#   }
# })

# %%
#compare to max elevation in bldg height -- Copernicus Digital Elevation Model (GLO-30 DEM)¶
